# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepanRaj10/Data-visualization-assignment/blob/main/Light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Feb  1 16:50:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    53W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !apt -get install python3.9
# Out:
# E: Command line option 'g' [from -get] is not understood in combination with the other options.

# %%
# !pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -uq "/content/drive/MyDrive/Light-DehazeNet.zip"  -d  "/content/"

# %%
# !unzip -uq "/content/drive/MyDrive/images.zip" -d "/content/Light-DehazeNet/data/original_images"

# %%
# !unzip -uq "/content/drive/MyDrive/data.zip" -d "/content/Light-DehazeNet/data/training_images"

# %%
cd Light-DehazeNet/
# Out:
# /content/Light-DehazeNet

# %%
# !python run_experiment.py -th data/training_images/data/ -to data/original_images/images/ -e 40 -lr 0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss at iteration 2370 : 0.013679331168532372
# Loss at iteration 2380 : 0.012636510655283928
# Loss at iteration 2390 : 0.006818313617259264
# Loss at iteration 2400 : 0.015518118627369404
# Loss at iteration 2410 : 0.014986368827521801
# Loss at iteration 2420 : 0.01968998834490776
# Loss at iteration 2430 : 0.02462775446474552
# Loss at iteration 2440 : 0.021183539181947708
# Loss at iteration 2450 : 0.010385783389210701
# Loss at iteration 2460 : 0.012431862764060497
# Loss at iteration 2470 : 0.010514513589441776
# Loss at iteration 2480 : 0.015528358519077301
# Loss at iteration 2490 : 0.012606363743543625
# Loss at iteration 2500 : 0.011632603593170643
# Loss at iteration 2510 : 0.01916191726922989
# Loss at iteration 2520 : 0.012375716120004654
# Loss at iteration 2530 : 0.011513860896229744
# Loss at iteration 2540 : 0.023550333455204964
# Loss at iteration 2550 : 0.008982597850263119
# ...

# %%
# !unzip -uq "/content/drive/MyDrive/Testing dataset.zip" -d "/content/Light-DehazeNet/"

# %%
# !python muliple_test_inference.py -td Testingdataset/SOTS/outdoor
# Out:
# Testingdataset/SOTS/outdoor
# 10
